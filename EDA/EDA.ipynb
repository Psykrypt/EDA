# %% [markdown]
# # Importing Libraries and loading the file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

Iris=pd.read_csv('Iris.csv')

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris=Iris.drop(['Id'],axis=1)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Understanding the data

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Plotting Graphs to visualize the data

# %% [markdown]
# ### Countplot

# %%
plt.title('Species count')
sns.countplot(iris['Species'])

# %% [markdown]
# ### Scatterplot

# %%
plt.figure(figsize=(8,5))
plt.title('Comparison between sepal width and length on the basis of species')
sns.scatterplot(x=iris['SepalLengthCm'],y= iris['SepalWidthCm'], hue = iris['Species'])

# %% [markdown]
# ### Histogram (Univariate Analysis)

# %%
sns.FacetGrid(iris,hue="Species").map(sns.distplot,"PetalWidthCm").add_legend()

# %%
sns.FacetGrid(iris,hue="Species").map(sns.distplot,"SepalLengthCm").add_legend()

# %%
sns.FacetGrid(iris,hue="Species").map(sns.distplot,"SepalWidthCm").add_legend()

# %%
sns.FacetGrid(iris,hue="Species").map(sns.distplot,"PetalLengthCm").add_legend()

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iris,hue="Species")

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x="Species",y="PetalLengthCm", data=iris)

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(x="Species",y="PetalLengthCm", data=iris)

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(iris.corr())

# %% [markdown]
# ### Conclusion

# %% [raw]
# 1.Dataset is balanced
# 2.We have four numerical columns and one target column
# 3.There's strong correlation between Petal width and petal length
# 4.Setosa species is mostly distinguishable
# 5.Versicolor and Verginica species are difficult to differentiate
